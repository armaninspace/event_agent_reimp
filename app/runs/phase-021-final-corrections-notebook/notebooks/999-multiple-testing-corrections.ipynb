# %% [markdown]
# # Multiple-Testing Corrections
#
# Final correction notebook for the governed evidence run.

# %% [markdown]
# # Multiple-Testing Corrections
#
# Schema: `phase-013.pvalues-multiple-testing.v1`
#
# Method: `Benjamini-Hochberg FDR correction`
#
# Result count: `8`
#
# ## Corrected Results
#
# ### exploratory:city_week:revenue_all
#
# - P-value: `2.9501799448767745e-05`
# - Adjusted p-value: `3.9335732598356994e-05`
# - Status: `ok`
#
# ### exploratory:city_week:merchants_all
#
# - P-value: `3.028291992674218e-69`
# - Adjusted p-value: `2.4226335941393745e-68`
# - Status: `ok`
#
# ### exploratory:msa_week:revenue_all
#
# - P-value: `4.3424595105896045e-29`
# - Adjusted p-value: `1.1579892028238945e-28`
# - Status: `ok`
#
# ### exploratory:msa_week:merchants_all
#
# - P-value: `1.566027480531768e-48`
# - Adjusted p-value: `6.264109922127072e-48`
# - Status: `ok`
#
# ### matched:city_week:revenue_all
#
# - P-value: `4.0094695135503316e-08`
# - Adjusted p-value: `8.018939027100663e-08`
# - Status: `ok`
#
# ### matched:city_week:merchants_all
#
# - P-value: `3.503733502443456e-07`
# - Adjusted p-value: `5.60597360390953e-07`
# - Status: `ok`
#
# ### matched:msa_week:revenue_all
#
# - P-value: `0.0002879099670045203`
# - Adjusted p-value: `0.0003290399622908803`
# - Status: `ok`
#
# ### matched:msa_week:merchants_all
#
# - P-value: `0.06810014888764189`
# - Adjusted p-value: `0.06810014888764189`
# - Status: `ok`

# %%
correction_contract = {
    'method': 'Benjamini-Hochberg FDR correction',
    'result_count': 8,
    'minimum_expected_results': 1,
}
assert correction_contract['result_count'] >= correction_contract['minimum_expected_results']
assert 'Benjamini-Hochberg' in correction_contract['method']
print('correction_contract_passed')
# Out:
# correction_contract_passed
