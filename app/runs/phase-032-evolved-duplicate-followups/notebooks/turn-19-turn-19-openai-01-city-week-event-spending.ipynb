# %% [markdown]
# # Turn 19: Which matched-control checks change the city game-week spending lift estimate after the baseline result?
#
# Selected candidate: `turn-19-openai-01-city-week-event-spending`

# %% [markdown]
# ## Validation Status
#
# Notebook status: `scaffolded`. Code execution is deferred to a later phase.

# %%
validation_contract = {
    'candidate_id': 'turn-19-openai-01-city-week-event-spending',
    'semantic_slot': 'city_week_event_spending',
    'notebook_status': 'scaffolded',
}
observed_contract = dict(validation_contract)
assert observed_contract == validation_contract
print('validation_contract_passed')
# Out:
# validation_contract_passed
